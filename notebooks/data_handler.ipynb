# %%
import os
import sys
import numpy as np
import pandas as pd
from datetime import datetime

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.Alpha9.pipeline.data_handler import DataHandler
from src.Alpha9.market.events import EventQueue
from src.Alpha9.utility import get_config, read_file

# %%
config = get_config.load()
data = read_file.read_data('train', 'data')

# %%
SYMBOLS = config['pipeline']['symbols']
SYMBOLS = [symbol.split('/')[0] for symbol in SYMBOLS]
event_queue = EventQueue()
date_format = "%Y-%m-%d %H:%M:%S"
START_DATE = datetime.strptime("2022-01-01 00:00:00", date_format)
END_DATE = datetime.strptime("2022-01-31 23:59:59", date_format)

# %%
data_handler = DataHandler(data, SYMBOLS, event_queue, START_DATE, END_DATE)

# %%
N = 5
for _ in range(N):
    data_handler.update_candles()

# %%
data_handler.get_latest_candle()
# Out:
# pandas.core.indexes.base.Index

# %%
data_handler.get_latest_candles(3)
# Out:
#                      ('macd-signal-pct', 'BNB')  ('macd-slope', 'BNB')  \
# timestamp
# 2022-01-01 02:00:00                    0.000539               0.337537
# 2022-01-01 03:00:00                    0.000898               0.302219
# 2022-01-01 04:00:00                    0.000722              -0.000122
#
#                      ('sar', 'BNB')  ('tema', 'BNB')  ('ppo', 'BNB')  \
# timestamp
# 2022-01-01 02:00:00       -0.005413         0.005772       -0.418497
# 2022-01-01 03:00:00       -0.003667         0.004210       -0.502750
# 2022-01-01 04:00:00       -0.008350        -0.001313       -0.573404
#
#                      ('lin-reg-slope', 'BNB')  ('ichi-cloud-trend', 'BNB')  \
# timestamp
# 2022-01-01 02:00:00                 -0.449670                     0.001255
# 2022-01-01 03:00:00                 -0.191429                     0.001834
# 2022-01-01 04:00:00                  0.007473                    -0.004175
#
#                      ('rsi', 'BNB')  ('stoch-osc-slowk', 'BNB')  \
# timestamp
# 2022-01-01 02:00:00       51.863373                   66.255638
# 2022-01-01 03:00:00       52.370097                   68.720001
# 2022-01-01 04:00:00       46.878539                   64.891519
#
#                      ('adx', 'BNB')  ...  ('adx', 'SOL')  \
# timestamp                            ...
# 2022-01-01 02:00:00       23.325324  ...       20.733553
# 2022-01-01 03:00:00       22.190719  ...       19.635482
# 2022-01-01 04:00:00       21.777246  ...       18.543217
#
#                      ('stoch-rsi', 'SOL')  ('bop', 'SOL')  ('natr', 'SOL')  \
# timestamp
# 2022-01-01 02:00:00              1.621002        0.029851         1.217879
# 2022-01-01 03:00:00              1.835789        0.281250         1.156078
# 2022-01-01 04:00:00            -12.631871       -0.919255         1.149637
#
#                      ('obv', 'SOL')  ('vwap', 'SOL')  ('mfi', 'SOL')  \
# timestamp
# 2022-01-01 02:00:00     77556129.03       172.668043       36.595608
# 2022-01-01 03:00:00     77575114.25       172.677441       36.182999
# 2022-01-01 04:00:00     77553220.13       172.698660       31.410603
#
#                      ('log-return', 'SOL')  ('vol-spike', 'SOL')  \
# timestamp
# 2022-01-01 02:00:00               0.000116             -0.590311
# 2022-01-01 03:00:00               0.001099             -0.540048
# 2022-01-01 04:00:00              -0.008420             -0.462501
#
#                      ('norm-volatility', 'SOL')
# timestamp
# 2022-01-01 02:00:00                    0.003878
# 2022-01-01 03:00:00                    0.003701
# 2022-01-01 04:00:00                    0.009388
#
# [3 rows x 76 columns]

# %%
data_handler.get_latest_candle_datetime()
# Out:
# Timestamp('2022-01-01 04:00:00')

# %%
val = "('sar', 'BNB')"
data_handler.get_latest_candle_value(val)
# Out:
# -0.0083495145631067

# %%
data_handler.get_latest_candles_value(val, 3)
# Out:
# timestamp
# 2022-01-01 02:00:00   -0.005413
# 2022-01-01 03:00:00   -0.003667
# 2022-01-01 04:00:00   -0.008350
# Name: ('sar', 'BNB'), dtype: float64
