# %%
import os
import sys
import numpy as np
import pandas as pd
from datetime import datetime

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.Alpha9.pipeline.data_handler import DataHandler
from src.Alpha9.market.events import EventQueue
from src.Alpha9.utility import get_config, read_file

# %%
config = get_config.load()
data = read_file.read_data('train', 'data')

# %%
SYMBOLS = config['pipeline']['symbols']
SYMBOLS = [symbol.split('/')[0] for symbol in SYMBOLS]
event_queue = EventQueue()
date_format = "%Y-%m-%d %H:%M:%S"
START_DATE = datetime.strptime("2022-01-01 00:00:00", date_format)
END_DATE = datetime.strptime("2022-01-31 23:59:59", date_format)

# %%
data_handler = DataHandler(data, SYMBOLS, event_queue, START_DATE, END_DATE)

# %%
N = 5
for _ in range(N):
    data_handler.update_candles()

# %%
data_handler.get_latest_candle()
# Out:
# (open, BNB)                 518.100000
# (high, BNB)                 518.500000
# (low, BNB)                  514.800000
# (close, BNB)                515.000000
# (volume, BNB)             13355.034000
#                               ...
# (vwap, SOL)                 172.698660
# (mfi, SOL)                   31.410603
# (log-return, SOL)            -0.008420
# (vol-spike, SOL)             -0.462501
# (norm-volatility, SOL)        0.009388
# Name: 2022-01-01 04:00:00, Length: 96, dtype: float64

# %%
data_handler.get_latest_candles(3)
# Out:
#                      (open, BNB)  (high, BNB)  (low, BNB)  (close, BNB)  \
# timestamp
# 2022-01-01 02:00:00        517.2        519.3       517.1         517.8
# 2022-01-01 03:00:00        517.8        518.8       517.3         518.1
# 2022-01-01 04:00:00        518.1        518.5       514.8         515.0
#
#                      (volume, BNB)  (macd-signal-pct, BNB)  (macd-slope, BNB)  \
# timestamp
# 2022-01-01 02:00:00      10209.673                0.000539           0.337537
# 2022-01-01 03:00:00       9973.326                0.000898           0.302219
# 2022-01-01 04:00:00      13355.034                0.000722          -0.000122
#
#                      (sar, BNB)  (tema, BNB)  (ppo, BNB)  ...  (adx, SOL)  \
# timestamp                                                 ...
# 2022-01-01 02:00:00   -0.005413     0.005772   -0.418497  ...   20.733553
# 2022-01-01 03:00:00   -0.003667     0.004210   -0.502750  ...   19.635482
# 2022-01-01 04:00:00   -0.008350    -0.001313   -0.573404  ...   18.543217
#
#                      (stoch-rsi, SOL)  (bop, SOL)  (natr, SOL)   (obv, SOL)  \
# timestamp
# 2022-01-01 02:00:00          1.621002    0.029851     1.217879  77556129.03
# 2022-01-01 03:00:00          1.835789    0.281250     1.156078  77575114.25
# 2022-01-01 04:00:00        -12.631871   -0.919255     1.149637  77553220.13
#
#                      (vwap, SOL)  (mfi, SOL)  (log-return, SOL)  \
# timestamp
# 2022-01-01 02:00:00   172.668043   36.595608           0.000116
# 2022-01-01 03:00:00   172.677441   36.182999           0.001099
# 2022-01-01 04:00:00   172.698660   31.410603          -0.008420
#
#                      (vol-spike, SOL)  (norm-volatility, SOL)
# timestamp
# 2022-01-01 02:00:00         -0.590311                0.003878
# 2022-01-01 03:00:00         -0.540048                0.003701
# 2022-01-01 04:00:00         -0.462501                0.009388
#
# [3 rows x 96 columns]

# %%
data_handler.get_latest_candle_datetime()
# Out:
# Timestamp('2022-01-01 04:00:00')

# %%
val = ('sar', 'BNB')
data_handler.get_latest_candle_value(val)
# Out:
# np.float64(-0.0083495145631067)

# %%
data_handler.get_latest_candles_value(val, 3)
# Out:
# timestamp
# 2022-01-01 02:00:00   -0.005413
# 2022-01-01 03:00:00   -0.003667
# 2022-01-01 04:00:00   -0.008350
# Name: (sar, BNB), dtype: float64

# %%
data_handler.visualize_data('rsi')
